# %% [markdown]
# This Notebook is used for cleaning wikibase data during tests.

# %%
from dotenv import load_dotenv

from wikibase_pipeline.config import load_env_config
from wikibase_pipeline.wikibase_api import WikibaseAPI

load_dotenv()
params = load_env_config()
api = WikibaseAPI(params["wikibase"])

# %%
api.delete_items_range(7001, 7743)

# %%
api.delete_properties_range(30, 60)
